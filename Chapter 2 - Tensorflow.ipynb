# %%
import tensorflow as tf
import numpy as np
import pandas as pd

# %%
tf.__version__
# Out:
# '2.20.0'

# %%
np.set_printoptions(precision=3)

# %%
a = np.array([1,2,3], dtype=np.int32)

# %%
b = [4,5,6]

# %%
a
# Out:
# array([1, 2, 3], dtype=int32)

# %%
b
# Out:
# [4, 5, 6]

# %%
t_a = tf.convert_to_tensor(a)

# %%
t_a
# Out:
# <tf.Tensor: shape=(3,), dtype=int32, numpy=array([1, 2, 3], dtype=int32)>

# %%
t_b = tf.convert_to_tensor(b)

# %%
t_b
# Out:
# <tf.Tensor: shape=(3,), dtype=int32, numpy=array([4, 5, 6], dtype=int32)>

# %%
print(t_a)
# Out:
# tf.Tensor([1 2 3], shape=(3,), dtype=int32)

# %%
print(t_b)
# Out:
# tf.Tensor([4 5 6], shape=(3,), dtype=int32)

# %%
t_ones = tf.ones((2,3))

# %%
t_ones
# Out:
# <tf.Tensor: shape=(2, 3), dtype=float32, numpy=
# array([[1., 1., 1.],
#        [1., 1., 1.]], dtype=float32)>

# %%
print(t_ones)
# Out:
# tf.Tensor(
# [[1. 1. 1.]
#  [1. 1. 1.]], shape=(2, 3), dtype=float32)

# %%
t_ones.numpy()
# Out:
# array([[1., 1., 1.],
#        [1., 1., 1.]], dtype=float32)

# %%
const_tensor = tf.constant([1.2, 5, np.pi],
                           dtype = tf.float32)

# %%
const_tensor
# Out:
# <tf.Tensor: shape=(3,), dtype=float32, numpy=array([1.2  , 5.   , 3.142], dtype=float32)>

# %%
print(const_tensor)
# Out:
# tf.Tensor([1.2   5.    3.142], shape=(3,), dtype=float32)

# %%
tf.random.set_seed(1)
t1 = tf.random.uniform(shape=(5,2),
                       minval=-1.0,
                       maxval=1.0)
t2 = tf.random.normal(shape=(5,2),
                      mean=0.0,
                      stddev=1.0)

# %%
t1 * t2
# Out:
# <tf.Tensor: shape=(5, 2), dtype=float32, numpy=
# array([[-0.27 , -0.874],
#        [-0.017, -0.175],
#        [-0.296, -0.139],
#        [-0.727,  0.135],
#        [-0.401,  0.004]], dtype=float32)>

# %%
t1
# Out:
# <tf.Tensor: shape=(5, 2), dtype=float32, numpy=
# array([[-0.67 ,  0.803],
#        [ 0.262, -0.131],
#        [-0.416,  0.285],
#        [ 0.952, -0.13 ],
#        [ 0.32 ,  0.21 ]], dtype=float32)>

# %%
tf.math.reduce_mean(t1, axis=0)
# Out:
# <tf.Tensor: shape=(2,), dtype=float32, numpy=array([0.09 , 0.207], dtype=float32)>

# %%
tf.linalg.matmul(t1, t2, transpose_b=True)
# Out:
# <tf.Tensor: shape=(5, 5), dtype=float32, numpy=
# array([[-1.144,  1.115, -0.87 , -0.321,  0.856],
#        [ 0.248, -0.191,  0.25 , -0.064, -0.331],
#        [-0.478,  0.407, -0.436,  0.022,  0.527],
#        [ 0.525, -0.234,  0.741, -0.593, -1.194],
#        [-0.099,  0.26 ,  0.125, -0.462, -0.396]], dtype=float32)>

# %%
tf.random.set_seed(1)
t_x = tf.random.uniform([4, 3], dtype=tf.float32)
t_y = tf.range(4)

# %%
t_x
# Out:
# <tf.Tensor: shape=(4, 3), dtype=float32, numpy=
# array([[0.165, 0.901, 0.631],
#        [0.435, 0.292, 0.643],
#        [0.976, 0.435, 0.66 ],
#        [0.605, 0.637, 0.614]], dtype=float32)>

# %%
t_y
# Out:
# <tf.Tensor: shape=(4,), dtype=int32, numpy=array([0, 1, 2, 3], dtype=int32)>

# %%
ds_x = tf.data.Dataset.from_tensor_slices(t_x)
ds_y = tf.data.Dataset.from_tensor_slices(t_y)

# %%
ds_joint = tf.data.Dataset.zip((ds_x, ds_y))

# %%
ds_joint
# Out:
# <_ZipDataset element_spec=(TensorSpec(shape=(3,), dtype=tf.float32, name=None), TensorSpec(shape=(), dtype=tf.int32, name=None))>

# %%
for example in ds_joint:
    print(example[0].numpy())
    print(example[1].numpy())
# Out:
# [0.165 0.901 0.631]
# 0
# [0.435 0.292 0.643]
# 1
# [0.976 0.435 0.66 ]
# 2
# [0.605 0.637 0.614]
# 3

# %%
ds_joint.batch(3)
# Out:
# <_BatchDataset element_spec=(TensorSpec(shape=(None, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %%
import tensorflow_datasets as tfds

# %%
len(tfds.list_builders())
# Out:
# 2026-05-07 20:22:05.569086: W external/local_xla/xla/tsl/platform/cloud/google_auth_provider.cc:185] All attempts to get a Google authentication bearer token failed, returning an empty token. Retrieving token from files failed with "NOT_FOUND: Could not locate the credentials file.". Retrieving token from GCE failed with "FAILED_PRECONDITION: Error executing an HTTP request: libcurl code 6 meaning 'Could not resolve hostname', error details: Could not resolve host: metadata.google.internal".
# 1315
