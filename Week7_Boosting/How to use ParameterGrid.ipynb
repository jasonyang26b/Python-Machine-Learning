# %%
from sklearn.model_selection import ParameterGrid
import time
import gc
import time

parameter_grid = {'num_leaves': [64, 128, 256],
                  'min_child_samples': [50, 100],
                  'learning_rate': [0.03, 0.05],
                  'colsample_bytree': [0.70, 0.90]}

final_grid = list(ParameterGrid(parameter_grid))
print("Number of configs:", len(final_grid))
# Out:
# Number of configs: 24

# %%
parameter_grid
# Out:
# {'num_leaves': [64, 128, 256],
#  'min_child_samples': [50, 100],
#  'learning_rate': [0.03, 0.05],
#  'colsample_bytree': [0.7, 0.9]}

# %%
ParameterGrid(parameter_grid)

# %%
list(ParameterGrid(parameter_grid))
# Out:
# [{'colsample_bytree': 0.7,
#   'learning_rate': 0.03,
#   'min_child_samples': 50,
#   'num_leaves': 64},
#  {'colsample_bytree': 0.7,
#   'learning_rate': 0.03,
#   'min_child_samples': 50,
#   'num_leaves': 128},
#  {'colsample_bytree': 0.7,
#   'learning_rate': 0.03,
#   'min_child_samples': 50,
#   'num_leaves': 256},
#  {'colsample_bytree': 0.7,
#   'learning_rate': 0.03,
#   'min_child_samples': 100,
#   'num_leaves': 64},
#  {'colsample_bytree': 0.7,
#   'learning_rate': 0.03,
#   'min_child_samples': 100,
#   'num_leaves': 128},
#  {'colsample_bytree': 0.7,
#   'learning_rate': 0.03,
#   'min_child_samples': 100,
#   'num_leaves': 256},
#  {'colsample_bytree': 0.7,
#   'learning_rate': 0.05,
#   'min_child_samples': 50,
#   'num_leaves': 64},
#  {'colsample_bytree': 0.7,
#   'learning_rate': 0.05,
#   'min_child_samples': 50,
#   'num_leaves': 128},
#  {'colsample_bytree': 0.7,
#   'learning_rate': 0.05,
#   'min_child_samples': 50,
#   'num_leaves': 256},
# ...
